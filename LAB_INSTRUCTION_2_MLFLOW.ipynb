# %% [markdown]
# # Laboratory 5 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration
#
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.
#
# You have two options for running MLflow:
#
# #### Option 1: Local MLflow (Simple)
# 1. Open terminal - we recommend to split it into 2 shells or just open additional session.
#
# 1. Create a directory for MLflow artifacts storage:
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5001
# ```
#
# ```bash windows
# .venv\Scripts\activate
# mlflow server --backend-store-uri sqlite:///mlflow.db --default-artifact-root ./mlflow-artifacts --host 0.0.0.0 --port 5001
# ```
#
# **Important: Keep this terminal window open.** The MLflow server will continue running and be accessible at http://localhost:5001
#
# #### Option 2: MLflow with Docker (Recommended for production-like setup)
#
# 1. Create a `docker-compose.yml` file:
# ```yaml
# services:
#   mlflow:
#     image: ghcr.io/mlflow/mlflow:v2.9.2
#     container_name: mlflow-server
#     ports:
#       - "5001:5000"
#     volumes:
#       - ./mlflow-data:/mlflow
#     command:
#       - mlflow
#       - server
#       - --backend-store-uri
#       - sqlite:////mlflow/mlflow.db
#       - --default-artifact-root
#       - /mlflow/artifacts
#       - --host
#       - 0.0.0.0
#       - --port
#       - "5000"
#     restart: unless-stopped
# ```
#
# 2. Start MLflow with Docker:
# ```bash
# docker compose down -v
# rm -rf mlflow-data
# mkdir -p mlflow-data/artifacts
# docker compose up -d
# ```
#
# 3. Check if it's running:
# ```bash
# docker-compose ps
# ```
#
# 4. View logs (optional):
# ```bash
# docker-compose logs -f mlflow
# ```
#
# 5. To stop the server later:
# ```bash
# docker-compose down
# ```
#
# **Important: Add MLflow files to .gitignore**
#
# MLflow creates local files that should not be committed to Git. Add these lines to your `.gitignore`:
#
# ```
# # MLflow
# mlflow.db
# mlflow-artifacts/
# mlruns/
# ```
#
# These files contain experiment data and artifacts that are specific to your local machine. In production, you would use a remote tracking server and artifact storage (like S3).

# %% [markdown]
# ### Connecting to MLflow
#
# To verify if the server runs properly, let's connect to it:
#
# ```python
# import mlflow
# import mlflow.sklearn
#
# import warnings
#
# warnings.filterwarnings("ignore")
#
# mlflow.set_tracking_uri("http://localhost:5001")
# print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# ```
#
# **To stop the MLflow server later:**
#
# - **Local setup**: Press `Ctrl+C` in the terminal where it's running
# - **Docker setup**: Run `docker-compose down`
#
# The server will shut down gracefully and save all your experiments.
#
# **Note:** Keep the server running throughout this lab session. All your experiments will be logged to this server instance.

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:5001")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:5001

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

# As we have temporal data, the best way to evaluate our model is time (chronological) 
# split, where the newest data is used for testing. We will assume that we have the 
# data #for years 2006 and 2007, and evaluate using data from 2008.

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a bunch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# 2026/04/07 15:41:39 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.0. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# <Experiment: artifact_location='file:///C:/Users/alwilczy/Desktop/prywatne/AGH_ISSI/sem2/MLOps_course_AGH-master/lab05/mlflow-artifacts/1', creation_time=1774811893173, experiment_id='1', last_update_time=1775303962137, lifecycle_stage='active', name='ames-housing-autolog', tags={}>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test, dvc_metadata=None):
    results = {}

    for model_name, model in models:
        if mlflow.active_run() is not None:
            mlflow.end_run()
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):                        
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()
            
            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            # Log DVC metadata if provided
            if dvc_metadata is not None:
                mlflow.log_param("MD5_hash", dvc_metadata["md5"])
                mlflow.log_param("file_size", dvc_metadata["size"])
                mlflow.log_param("data_path", dvc_metadata["path"])
            
            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test, dvc_metadata)
# Out:
# 2026/04/07 15:41:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:57 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:57 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:57 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.880 ± 0.037
# 🏃 View run Ridge Regression at: http://localhost:5001/#/experiments/1/runs/d84b3bc0f25c4915a58de243cbab5bdb
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 15:41:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:41:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.726 ± 0.080
# 🏃 View run Decision Tree at: http://localhost:5001/#/experiments/1/runs/1a5f47413f5f4a80aeddf65685a6d266
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 15:42:02 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:03 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# K-Nearest Neighbors:
#   RMSE: 38325.08
#   MAE: 26034.48
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.656 ± 0.050
# 🏃 View run K-Nearest Neighbors at: http://localhost:5001/#/experiments/1/runs/7b6909345ca14693a99813911657f498
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 15:42:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:14 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:17 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:20 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:23 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25896.23
#   MAE: 15509.71
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.870 ± 0.043
# 🏃 View run Random Forest at: http://localhost:5001/#/experiments/1/runs/3565376de5764cc59de71e0d72d37f85
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2026/04/07 15:42:25 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:26 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:27 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:29 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/04/07 15:42:30 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Gradient Boosting:
#   RMSE: 21572.13
#   MAE: 13809.38
#   R^2: 0.919
#   CV R^2 (mean ± std): 0.898 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:5001/#/experiments/1/runs/131237a2cb7b49018a75c78adb655d5a
# 🧪 View experiment at: http://localhost:5001/#/experiments/1

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %% [markdown]
# ## 2.3 Connecting DVC and MLflow
#
# You've already used DVC to version your dataset in the first part of this lab. Now let's connect DVC metadata with MLflow experiments to create a complete audit trail. When you run experiments, you want to know:
# - Which version of the data was used?
# - Can I reproduce these exact results?
# - What changed between experiments?
#
# By logging DVC metadata in MLflow, you create a link between your data versions and experiment results.

# %% [markdown]
# ### Reading DVC metadata
#
# DVC stores metadata in `.dvc` files. Let's read it:

# %%
import yaml

def get_dvc_metadata(dvc_file_path):
    with open(dvc_file_path, 'r') as f:
        dvc_data = yaml.safe_load(f)
    
    metadata = {
        'md5': dvc_data['outs'][0]['md5'],
        'size': dvc_data['outs'][0]['size'],
        'path': dvc_data['outs'][0]['path']
    }
    return metadata

dvc_metadata = get_dvc_metadata('data/ames_data_2006_2008.parquet.dvc')
print("DVC Metadata:")
print(f"MD5 hash: {dvc_metadata['md5']}")
print(f"File size: {dvc_metadata['size']} bytes")
print(f"Data path: {dvc_metadata['path']}")
# Out:
# DVC Metadata:
# MD5 hash: f44053333f88a0646819936b37f000ee
# File size: 162560 bytes
# Data path: ames_data_2006_2008.parquet

# %% [markdown]
# ### Exercise 1 - Logging DVC metadata in MLflow
#
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Now let's modify our training to include DVC metadata. This creates a complete audit trail:
# - **Git commit** → tracks code version
# - **DVC hash** → tracks data version
# - **MLflow run** → tracks experiment results
#
# Your task is to:
# 1. Run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again.
# 2. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
# 3. Make sure you have included DVC metadata logging. You can initialize dvc_metadata by calling above defined `get_dvc_metadata` function with the .dvc metadata file. Then you can just for each experiment add param logging like:
#
# ```python
# mlflow.log_param("param_name", "value you want to log") # e.g md5
# ```

# %%
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import TweedieRegressor
from sklearn.linear_model import ElasticNet
from sklearn.gaussian_process import GaussianProcessRegressor

additional_models = [
    ("Support Vector Regression", SVR(kernel='rbf', C=1.0, epsilon=0.1)),
    ("AdaBoost Regression", AdaBoostRegressor(n_estimators=100, random_state=42)),
    ("Tweedie Regression", TweedieRegressor(power=1, alpha=0.5, max_iter=1000)),
    ("Elastic Net", ElasticNet(alpha=1.0, l1_ratio=0.5, random_state=42)),
    ("Gaussian Process Regression", GaussianProcessRegressor(random_state=42)),
]

# %%
fit_sklearn_models_with_cv(additional_models, X_train, X_test, y_train, y_test, dvc_metadata)
# Out:
# Support Vector Regression:
#   RMSE: 77482.01
#   MAE: 54914.40
#   R^2: -0.051
#   CV R^2 (mean ± std): -0.129 ± 0.135
# 🏃 View run Support Vector Regression at: http://localhost:5001/#/experiments/2/runs/886213343ad2423697b6aa009e747b25
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# AdaBoost Regression:
#   RMSE: 31826.35
#   MAE: 23057.82
#   R^2: 0.823
#   CV R^2 (mean ± std): 0.803 ± 0.077
# 🏃 View run AdaBoost Regression at: http://localhost:5001/#/experiments/2/runs/d626056e187a4d5395421c45aeb61aa1
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# Tweedie Regression:
#   RMSE: 21113.06
#   MAE: 13798.30
#   R^2: 0.922
#   CV R^2 (mean ± std): 0.883 ± 0.061
# 🏃 View run Tweedie Regression at: http://localhost:5001/#/experiments/2/runs/cae2077fc0b8425893e76103630f8321
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# Elastic Net:
#   RMSE: 43029.14
#   MAE: 29452.37
#   R^2: 0.676
#   CV R^2 (mean ± std): 0.597 ± 0.054
# 🏃 View run Elastic Net at: http://localhost:5001/#/experiments/2/runs/a08bb55e22614bf093d69d79c0f241d3
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
#
# Gaussian Process Regression:
#   RMSE: 162799.40
#   MAE: 148233.18
#   R^2: -3.639
#   CV R^2 (mean ± std): -3.614 ± 1.062
# 🏃 View run Gaussian Process Regression at: http://localhost:5001/#/experiments/2/runs/ba299556346d42518dae4b075bc3080d
# 🧪 View experiment at: http://localhost:5001/#/experiments/2

# %% [markdown]
# Root Mean Squared Error (RMSE) comparison:
# 1. Tweedie Regression: RMSE = 21 113.06
# 2. Gradient Boosting: RMSE = 21 572.13
# 3. Ridge Regression: RMSE = 23 450.39
# 4. Random Forest: RMSE = 25 896.23
# 5. AdaBoost Regression: RMSE = 31 826.35
# 6. Decision Tree: RMSE = 36 860.51
# 7. K-Nearest Neighbors: RMSE = 38 325.08
# 8. Elastic Net: RMSE = 43 029.14
# 9. Support Vector Regression: RMSE = 77 482.01
# 10. Gaussian Process Regression: RMSE = 162 799.40
#
# Tweedie Regression and Gradient Boosting are the most accurate models (lowest RMSE), while Gaussian Process Regression and Support Vector Regression perform the worst (highest RMSE).

# %% [markdown]
# Mean Absolute Error (MAE) comparison:
# 1. Tweedie Regression: MAE = 13,798.30
# 2. Gradient Boosting: MAE = 13,809.38
# 3. Random Forest: MAE = 15,509.71
# 4. Ridge Regression: MAE = 16,430.79
# 5. AdaBoost Regression: MAE = 23,057.82
# 6. Decision Tree: MAE = 23,270.66
# 7. K-Nearest Neighbors: MAE = 26,034.48
# 8. Elastic Net: MAE = 29,452.37
# 9. Support Vector Regression: MAE = 54,914.40
# 10. Gaussian Process Regression: MAE = 148,233.18
#
# Tweedie Regression and Gradient Boosting have the lowest MAE (most accurate), while Gaussian Process Regression and Support Vector Regression have the highest MAE (least accurate).

# %% [markdown]
# R^2 and CV R^2 comparison:
# 1. No clear overfitting is present in any scikit-learn experiment. For all models, the test R^2 is similar to or slightly higher than the CV R^2.
# 2. Support Vector Regression, Gaussian Process Regression, Elastic Net models show low or negative R^2 and CV R^2, indicating underfitting or poor model choice.

# %% [markdown]
# ![Alt text](screenshots/Exercise1.png)

# %% [markdown]
# ## 3. Manual logging with PyTorch
#
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but we often need low-level control of pure PyTorch.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual")
# Out:
# <Experiment: artifact_location='file:///C:/Users/alwilczy/Desktop/prywatne/AGH_ISSI/sem2/MLOps_course_AGH-master/lab05/mlflow-artifacts/2', creation_time=1775318261703, experiment_id='2', last_update_time=1775318261703, lifecycle_stage='active', name='pytorch-housing-manual', tags={}>

# %% [markdown]
# ### 3.1 Targets transformation
#
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
import matplotlib.pyplot as plt

y_train.plot.hist()
plt.show()

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them.

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
plt.show()

# %% [markdown]
# ### 3.2 Define and train the model
#
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(
        self, model_class: type[nn.Module], config: dict
    ):
        required_keys = ['hidden_units', 'dropout', 'batch_size', 'learning_rate', 
                         'log_interval', 'epochs', 'name']
        missing = [key for key in required_keys if key not in config]
        if missing:
            raise ValueError(f"Missing required config keys: {missing}")
        
        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()
        
        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.numpy())
        y_test = y_test.numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)
            
            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def _log_dvc_metadata(self, dvc_file_path: str = 'data/ames_data_2006_2008.parquet.dvc'):
        try:
            dvc_metadata = get_dvc_metadata(dvc_file_path)
            
            mlflow.log_param("data_dvc_md5", dvc_metadata['md5'])
            mlflow.log_param("data_dvc_size", dvc_metadata['size'])
            mlflow.log_param("data_path", dvc_metadata['path'])
            print(f"Logged DVC metadata: {dvc_metadata['md5'][:8]}...")
        except FileNotFoundError:
            print("DVC file not found - skipping metadata logging")
        except Exception as e:
            print(f"Could not log DVC metadata: {e}")

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)
            
            # Log DVC metadata for data versioning
            self._log_dvc_metadata()

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)
        
        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))
        
        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")
        
        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
    
    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.
#
# ### Configuration
# `base_config` contains **fixed parameters** that stay the same across all experiments:
# - `model_class`: The neural network architecture we're using (HousePriceNet)
# - `random_seed`: For reproducibility (42)
# - `log_interval`: How often to log metrics during training (every 5 epochs)
# - `num_samples`: Dataset size
# - `input_features`: Number of input features
# - `k_folds`: Number of cross-validation folds (5)
#
# `experiment_config` contains **hyperparameters** we want to tune:
# - `name`: Unique identifier for this experiment run
# - `hidden_units`: Size of the hidden layer (128, 256, 512, etc.)
# - `dropout`: Dropout rate for regularization (0.0 to 0.5)
# - `learning_rate`: Step size for gradient descent (0.001 to 0.1)
# - `epochs`: Number of training iterations (50, 100, 150, etc.)
# - `batch_size`: Number of samples per training batch (16, 32, 64, etc.)
#
# If you want you can deliver your own NeuralNetwork model, and just specify in experiment_config: `{"model_class": YourOwnModel}` it will overwrite the our base `HousePriceNet`

# %% [markdown]
# #### 3. Merging configurations
# We use Python's dictionary merge operator `|` to combine them:
# ```python
# training_config = base_config | experiment_config
# ```
#
# This creates a single configuration dictionary with all parameters. The `experiment_config` values override any duplicate keys from `base_config`, allowing us to easily experiment with different hyperparameters while keeping the base setup constant.
#
# Now let's set up our first experiment:

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

experiment_config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | experiment_config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 26619.68, MAE: 18240.99 R^2: 0.885
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 28239.29, MAE: 18617.18 R^2: 0.865
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 25163.80, MAE: 18146.23 R^2: 0.911
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 47058.52, MAE: 34217.66 R^2: 0.633
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 40672.91, MAE: 30075.88 R^2: 0.743
#
# Cross-validation complete. Mean R^2: 0.807 (+/- 0.104)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.807 (+/- 0.104)
#
# Cross-Validation Performance:
#   R^2: 0.883
#   RMSE: 25806.97
#   MAE: 18270.76
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:5001/#/experiments/2/runs/b0e9e614d7674cd19e979b450b7da873
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# {'rmse': 25806.970703125,
#  'mae': 18270.755859375,
#  'r2': 0.8834378719329834,
#  'cv_r2_mean': np.float64(0.8073758363723755),
#  'cv_r2_std': np.float64(0.10439640858489882),
#  'cv_scores': [0.8849228024482727,
#   0.8651313781738281,
#   0.9106823205947876,
#   0.6332787275314331,
#   0.7428639531135559]}

# %% [markdown]
# ### Exercise 2
#
# Your task is to:
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# **How to modify configurations:**
#
# You have two approaches:
#
# #### Approach 1: Loop through multiple configurations (Recommended for systematic exploration)
#
# Define a list of experiment configurations and iterate through them. Each configuration dictionary should contain only the hyperparameters you want to tune (name, hidden_units, dropout, learning_rate, epochs, batch_size). The base_config stays the same.
#
# ```python
# base_config = {
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],  # Number of features (181)
#     "num_samples": X_train.shape[0],     # Dataset size (1312)
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# # Define multiple experiments to run
# configs = [
#     {
#         "name": "baseline_128_units",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     },
#     {
#         "name": "larger_network_256",
#         "hidden_units": 256,        # Try larger network
#         "dropout": 0.2,             # More dropout for regularization
#         "learning_rate": 0.01,      # Lower learning rate
#         "epochs": 200,
#         "batch_size": 64,
#     },
#     {
#         "name": "high_regularization",
#         "hidden_units": 128,
#         "dropout": 0.3,             # Even more dropout
#         "learning_rate": 0.01,
#         "epochs": 150,
#         "batch_size": 32,
#     },
#     # Add 7 more configurations here...
# ]
#
# # Run all experiments
# for experiment_config in configs:
#     training_config = base_config | experiment_config
#
#     trainer = PyTorchTrainer(training_config["model_class"], training_config)
#     results = trainer.fit(X_train, y_train_log, X_test, y_test)
# ```
#
# #### Approach 2: Manual and incremental (Good for quick iterations)
#
# Run experiments one by one, adjusting hyperparameters based on previous results:
#
# ```python
# # First experiment
# experiment_config = {
#     "name": "experiment_01_baseline",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | experiment_config
# trainer = PyTorchTrainer(training_config["model_class"], training_config)
# results = trainer.fit(X_train, y_train_log, X_test, y_test)
# ```
# After analyzing results in MLflow, run another experiment
#
# ```
# experiment_config = {
#     "name": "experiment_02_more_dropout",
#     "hidden_units": 128,
#     "dropout": 0.3,  # Increased from 0.1
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | experiment_config
# trainer = PyTorchTrainer(training_config["model_class"], training_config)
# results = trainer.fit(X_train, y_train_log, X_test, y_test)
#
# # Continue with more experiments
# ```

# %% [markdown]
# **Tips for hyperparameter tuning:**
# - Start with one change at a time to understand its impact
# - Use meaningful experiment names that describe what you changed
# - Check MLflow UI after each experiment to guide your next choice
# - Look for signs of overfitting: high training performance but poor test performance
# - Watch the training curves in MLflow's "Model metrics" tab

# %%
configs = [
    {
        "name": "baseline_128_units",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "larger_network_256",
        "hidden_units": 256,        # Try larger network
        "dropout": 0.2,             # More dropout for regularization
        "learning_rate": 0.01,      # Lower learning rate
        "epochs": 200,
        "batch_size": 64,    
    },
    {
        "name": "smaller_network_64",
        "hidden_units": 64,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 100,
        "batch_size": 32,
    },
    {
        "name": "very_large_network_512",
        "hidden_units": 512,
        "dropout": 0.2,
        "learning_rate": 0.005,
        "epochs": 250,
        "batch_size": 64,
    },
    {
        "name": "high_regularization",
        "hidden_units": 128,
        "dropout": 0.3,             # Even more dropout
        "learning_rate": 0.01,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "low_dropout",
        "hidden_units": 128,
        "dropout": 0.05,
        "learning_rate": 0.02,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "high_lr",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.1,
        "epochs": 100,
        "batch_size": 32,
    },
    {
        "name": "small_batch",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 8,
    },
    {
        "name": "large_batch",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 256,
    },
    {
        "name": "long_training",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.01,
        "epochs": 500,
        "batch_size": 32,
    },
]

# %%
for config in configs:
    training_config = base_config | config
    
    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for baseline_128_units...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 24293.11, MAE: 17548.05 R^2: 0.904
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 25375.51, MAE: 19355.35 R^2: 0.891
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 44847.79, MAE: 34906.12 R^2: 0.716
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 51150.90, MAE: 36766.68 R^2: 0.567
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 28252.13, MAE: 19743.92 R^2: 0.876
#
# Cross-validation complete. Mean R^2: 0.791 (+/- 0.131)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.791 (+/- 0.131)
#
# Cross-Validation Performance:
#   R^2: 0.892
#   RMSE: 24868.23
#   MAE: 18006.46
# Test Set Performance:
# ==================================================
# FINAL RESULTS for baseline_128_units:
#
# ==================================================
# 🏃 View run baseline_128_units at: http://localhost:5001/#/experiments/2/runs/c95fbe80877243f2909d721e90243b76
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for larger_network_256...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 57156.80, MAE: 32189.84 R^2: 0.469
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 43126.95, MAE: 32014.40 R^2: 0.685
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 59887.92, MAE: 44760.46 R^2: 0.494
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 41234.16, MAE: 30786.15 R^2: 0.718
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 42553.43, MAE: 30867.46 R^2: 0.719
#
# Cross-validation complete. Mean R^2: 0.617 (+/- 0.111)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.617 (+/- 0.111)
#
# Cross-Validation Performance:
#   R^2: -0.177
#   RMSE: 81991.51
#   MAE: 69855.37
# Test Set Performance:
# ==================================================
# FINAL RESULTS for larger_network_256:
#
# ==================================================
# 🏃 View run larger_network_256 at: http://localhost:5001/#/experiments/2/runs/0e8ab495dab94f078163b6ab398a252e
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for smaller_network_64...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 45251.65, MAE: 32168.74 R^2: 0.667
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 43292.10, MAE: 35892.81 R^2: 0.683
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 46087.61, MAE: 33453.59 R^2: 0.700
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 55180.47, MAE: 38020.38 R^2: 0.496
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 38094.89, MAE: 27820.88 R^2: 0.774
#
# Cross-validation complete. Mean R^2: 0.664 (+/- 0.092)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.664 (+/- 0.092)
#
# Cross-Validation Performance:
#   R^2: 0.884
#   RMSE: 25791.95
#   MAE: 17688.68
# Test Set Performance:
# ==================================================
# FINAL RESULTS for smaller_network_64:
#
# ==================================================
# 🏃 View run smaller_network_64 at: http://localhost:5001/#/experiments/2/runs/49d7079087cf44a2b7b3ebc74a46352a
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for very_large_network_512...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 103695.19, MAE: 55885.12 R^2: -0.746
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 42929.09, MAE: 31163.30 R^2: 0.688
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 38655.04, MAE: 28821.18 R^2: 0.789
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 53673.34, MAE: 43619.58 R^2: 0.523
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 56989.56, MAE: 39902.29 R^2: 0.495
#
# Cross-validation complete. Mean R^2: 0.350 (+/- 0.559)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.350 (+/- 0.559)
#
# Cross-Validation Performance:
#   R^2: 0.392
#   RMSE: 58921.63
#   MAE: 41489.63
# Test Set Performance:
# ==================================================
# FINAL RESULTS for very_large_network_512:
#
# ==================================================
# 🏃 View run very_large_network_512 at: http://localhost:5001/#/experiments/2/runs/2b4fe1ea4a02497ab6b23e9fd1b382e5
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for high_regularization...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 64458.23, MAE: 52118.82 R^2: 0.325
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 28304.38, MAE: 21067.18 R^2: 0.865
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 27846.09, MAE: 20046.98 R^2: 0.891
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 33713.10, MAE: 24605.70 R^2: 0.812
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 51355.51, MAE: 42559.11 R^2: 0.590
#
# Cross-validation complete. Mean R^2: 0.696 (+/- 0.214)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.696 (+/- 0.214)
#
# Cross-Validation Performance:
#   R^2: 0.562
#   RMSE: 50051.84
#   MAE: 40538.76
# Test Set Performance:
# ==================================================
# FINAL RESULTS for high_regularization:
#
# ==================================================
# 🏃 View run high_regularization at: http://localhost:5001/#/experiments/2/runs/b67cb4f54b5e44b3a239e55bc471137a
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for low_dropout...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 96932.18, MAE: 70939.55 R^2: -0.526
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 44340.39, MAE: 30627.72 R^2: 0.667
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 33839.44, MAE: 25613.64 R^2: 0.838
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 40787.12, MAE: 32759.02 R^2: 0.725
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 50162.29, MAE: 35686.78 R^2: 0.609
#
# Cross-validation complete. Mean R^2: 0.463 (+/- 0.500)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.463 (+/- 0.500)
#
# Cross-Validation Performance:
#   R^2: 0.375
#   RMSE: 59782.04
#   MAE: 45102.50
# Test Set Performance:
# ==================================================
# FINAL RESULTS for low_dropout:
#
# ==================================================
# 🏃 View run low_dropout at: http://localhost:5001/#/experiments/2/runs/810a7c2d5881409a9721b97fdbeaf68d
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for high_lr...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 24694.48, MAE: 17593.44 R^2: 0.901
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 27031.33, MAE: 18855.85 R^2: 0.876
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 21795.34, MAE: 15336.54 R^2: 0.933
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 26204.79, MAE: 17362.46 R^2: 0.886
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 27106.60, MAE: 17598.75 R^2: 0.886
#
# Cross-validation complete. Mean R^2: 0.896 (+/- 0.020)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.896 (+/- 0.020)
#
# Cross-Validation Performance:
#   R^2: 0.878
#   RMSE: 26381.42
#   MAE: 19121.61
# Test Set Performance:
# ==================================================
# FINAL RESULTS for high_lr:
#
# ==================================================
# 🏃 View run high_lr at: http://localhost:5001/#/experiments/2/runs/a4a908f76dce49fb9a7e6d255b096fc8
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for small_batch...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 53323.48, MAE: 36557.39 R^2: 0.538
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 26539.48, MAE: 18677.40 R^2: 0.881
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 33807.20, MAE: 25007.73 R^2: 0.839
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 43124.59, MAE: 28960.16 R^2: 0.692
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 39325.75, MAE: 29457.18 R^2: 0.760
#
# Cross-validation complete. Mean R^2: 0.742 (+/- 0.121)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.742 (+/- 0.121)
#
# Cross-Validation Performance:
#   R^2: 0.810
#   RMSE: 32925.56
#   MAE: 23598.64
# Test Set Performance:
# ==================================================
# FINAL RESULTS for small_batch:
#
# ==================================================
# 🏃 View run small_batch at: http://localhost:5001/#/experiments/2/runs/efc7c8bbf76e46eaaa5455a902c3d81e
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for large_batch...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 78727.20, MAE: 62180.81 R^2: -0.007
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 108881.59, MAE: 94801.54 R^2: -1.005
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 77105.44, MAE: 52063.19 R^2: 0.161
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 58319.71, MAE: 47980.48 R^2: 0.437
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 195744.66, MAE: 153298.73 R^2: -4.956
#
# Cross-validation complete. Mean R^2: -1.074 (+/- 2.001)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: -1.074 (+/- 2.001)
#
# Cross-Validation Performance:
#   R^2: 0.594
#   RMSE: 48181.24
#   MAE: 35095.62
# Test Set Performance:
# ==================================================
# FINAL RESULTS for large_batch:
#
# ==================================================
# 🏃 View run large_batch at: http://localhost:5001/#/experiments/2/runs/c03084749c044d9c9fd6ea61a528792c
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for long_training...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 22292.34, MAE: 15396.52 R^2: 0.919
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 25078.84, MAE: 17373.45 R^2: 0.894
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 23337.15, MAE: 15955.15 R^2: 0.923
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 26411.04, MAE: 18897.05 R^2: 0.884
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 35763.96, MAE: 22807.12 R^2: 0.801
#
# Cross-validation complete. Mean R^2: 0.884 (+/- 0.044)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.884 (+/- 0.044)
#
# Cross-Validation Performance:
#   R^2: 0.870
#   RMSE: 27268.01
#   MAE: 17482.32
# Test Set Performance:
# ==================================================
# FINAL RESULTS for long_training:
#
# ==================================================
# 🏃 View run long_training at: http://localhost:5001/#/experiments/2/runs/696d0591fd68497ab433a47c57a20ecd
# 🧪 View experiment at: http://localhost:5001/#/experiments/2

# %% [markdown]
# ![Alt text](screenshots/Exercise2.png)

# %% [markdown]
# The most impactful changes on model performance:
# 1. Increasing training duration (long_training) and learning rate (high_lr) led to the best results, with high and stable mean R^2 (0.884 and 0.896), indicating strong generalization and effective learning.
# 2. Simpler network architectures (smaller_network_64, baseline_128_units) outperformed larger models, suggesting that smaller models are better suited for this dataset.

# %% [markdown]
# Changes that disrupted the training process:
# 1. Large batch size (large_batch), large/very large networks (256 and 512 units), and low dropout (low_dropout) led to unstable or failed training, as shown by negative or low mean R² and high RMSE/MAE values. These settings likely caused optimization issues or overfitting, resulting in poor generalization.
# 2. High regularization (high_regularization) reduced overfitting but also decreased overall model performance.

# %% [markdown]
# Summary of the impact:
# The most positive impact came from tuning the learning rate (high_lr) and increasing training duration (long_training), which significantly improved generalization, model stability, and reduced overfitting. In contrast, increasing network size (larger_network_256, very_large_network_512), using large batch sizes (large_batch), or reducing/removing dropout (low_dropout) led to much worse performance and, in some cases, failed training (negative R^2). Regularization and dropout were effective in controlling overfitting, but excessive regularization reduced overall model accuracy and performance.
#
# Conclusion:
# The best results were achieved by optimizing the learning rate and training duration, rather than increasing model complexity. Overfitting was most effectively controlled with appropriate regularization and dropout. Excessive model size, large batch sizes, or poor regularization settings disrupted training, leading to instability and poor generalization.

# %% [markdown]
# First scikit-learn configuration (best model: Gradient Boosting):
# Test R^2: 0.919
# Test RMSE: 21572.13
# Test MAE: 13809.38
# CV R^2 (mean ± std): 0.898 ± 0.031
#
# First PyTorch experiment:
# Test R^2: 0.883
# Test RMSE: 25806.97
# Test MAE: 18270.76
# CV R^2 (mean ± std): 0.807 ± 0.104
#
# Analysis for overfitting in PyTorch experiment (first_run):
# The CV R^2 mean is 0.807 with a high standard deviation (0.104), indicating inconsistent performance across folds.
# The test set R^2 is 0.883, which is significantly higher than the CV mean R^2 which is 0.807.
# Normally, if a model is overfitting, the test set performance is worse than the cross-validation (or training) performance. Here the test R^2 is actually higher than the CV mean R^2, which is unusual and suggests that the test set may be easier or more similar to the training data, or that the CV splits were not representative.
# The large standard deviation in CV R^2 (0.104) and the low R^2 in some folds (e.g., 0.633, 0.743) indicate instability and possible overfitting to certain folds.
#
# Signs of Overfitting:
# Large gap between training (or CV) and test performance (test much worse) is a classic sign, but here the test is better.
# High variance in CV scores (as seen here) can indicate the model is sensitive to the data split, which is a sign of overfitting.
# Some folds perform much worse than others (training fold 4: R^2 = 0.633), suggesting the model cannot generalize well to all subsets.
#
# Conclusion:
# There is no classic overfitting (where test performance is much worse than CV/training), but the high variance in CV scores and poor performance on some folds suggest the model is unstable and may be overfitting to certain data patterns.
# The scikit-learn Gradient Boosting model shows higher and more stable performance (higher mean CV R^2, lower std, better test metrics), indicating better generalization.

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.

# %% [markdown]
# ```bash
# jupyter nbconvert --to html LAB_INSTRUCTION_2_MLFLOW.ipynb
# ```
